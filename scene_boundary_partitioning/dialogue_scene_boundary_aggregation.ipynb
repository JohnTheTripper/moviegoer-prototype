# %% [markdown]
# # dialogue_scene_boundary_aggregation
#
# We've previously been able to identify two-character dialogue scenes given an arbitrary series of input frames. Next we'll use those functions to identify scenes throughout an entire film.

# %%
import os
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras import models
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans, AgglomerativeClustering
from scene_cluster_io import *
# Out:
# Using TensorFlow backend.

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Arbitrary Input Frames
# Here's an example of the end-to-end process of generating scenes. An arbitrary range of input frames is used.

# %%
film = 'extremely_wicked'
frame_choice = list(range(650, 1050))
threshold = 3000

dialogue_folder = os.path.join('dialogue_frames', film)
print('There are', len(os.listdir(dialogue_folder)), 'images in the folder')
print('Selected', len(frame_choice), 'of those frames')

hac_labels = label_clusters(dialogue_folder, frame_choice, film, threshold)
# Out:
# There are 6603 images in the folder
# Selected 400 of those frames
# Number of clusters: 18

# %%
tuned_model = models.load_model('saved_models/tuned_model')

# %%
y_pred_values = predict_mcu(dialogue_folder, tuned_model, frame_choice, film)

# %%
shot_id_list = get_shot_ids(frame_choice, hac_labels)

# %%
scene_df = pd.DataFrame(zip(frame_choice, hac_labels, shot_id_list, y_pred_values), columns=['frame_file', 'cluster', 'shot_id', 'mcu'])
scene_df.head(3)
# Out:
#    frame_file  cluster  shot_id  mcu
# 0         650        2        0    1
# 1         651        2        0    1
# 2         652        2        0    1

# %%
alternating_pairs = get_alternating_pairs(frame_choice, hac_labels, y_pred_values, shot_id_list)
alternating_pairs
# Out:
# [[0, 2], [9, 13], [0, 1], [5, 10], [0, 6]]

# %%
speaker_pairs = mcu_check(alternating_pairs, scene_df)
speaker_pairs
# Out:
# cluster	 count	 mcu probability
# 0 	 165 	 48.48%
# 2 	 61 	 65.57%
# Fails MCU check
#
# 9 	 28 	 96.43%
# 13 	 21 	 100.00%
# Passes MCU check
#
# 0 	 165 	 48.48%
# 1 	 9 	 66.67%
# Fails MCU check
#
# 5 	 23 	 95.65%
# 10 	 17 	 100.00%
# Passes MCU check
#
# 0 	 165 	 48.48%
# 6 	 9 	 55.56%
# Fails MCU check
# [[9, 13], [5, 10]]

# %%
anchors = anchor_scenes(speaker_pairs, scene_df)
anchors
# Out:
# Speaker A and B Clusters: [9, 13]
# Anchor Start/End Frames: 690 743
#
# Speaker A and B Clusters: [5, 10]
# Anchor Start/End Frames: 954 997
# [(690, 743), (954, 997)]

# %%
scenes = expand_scenes(speaker_pairs, scene_df)
scenes
# Out:
# Speaker A and B Clusters: [9, 13]
# Anchor Start/End Frames: 690 743
# Cutaway Clusters: [0]
# Expanded Start/End Frames: 690 745
#
# Speaker A and B Clusters: [5, 10]
# Anchor Start/End Frames: 954 997
# Cutaway Clusters: [16]
# Expanded Start/End Frames: 954 997
# [(690, 745), (954, 997)]

# %% [markdown]
# ## Functions
# This entire process can be bundled into a single function `generate_scenes()`, encompassing all the individual functions. It returns a list of `(scene_start, scene_end)`.

# %%
def generate_scenes(film, frame_choice, threshold):
    dialogue_folder = os.path.join('dialogue_frames', film)

    hac_labels = label_clusters(dialogue_folder, frame_choice, film, threshold)
    print()
    y_pred_values = predict_mcu(dialogue_folder, tuned_model, frame_choice, film)
    shot_id_list = get_shot_ids(frame_choice, hac_labels)
    scene_df = pd.DataFrame(zip(frame_choice, hac_labels, shot_id_list, y_pred_values), columns=['frame_file', 'cluster', 'shot_id', 'mcu'])
    alternating_pairs = get_alternating_pairs(frame_choice, hac_labels, y_pred_values, shot_id_list)
    speaker_pairs = mcu_check(alternating_pairs, scene_df)
    anchors = anchor_scenes(speaker_pairs, scene_df)
    scenes = expand_scenes(speaker_pairs, scene_df)

    return scenes

# %% [markdown]
# We plan to use the above function repeatedly throughout the entire film, which presents a problem: each time the function is called, it returns a list, so we'll end up with a list of lists. The below function will take a list of lists and return a flat list, with duplicates removed, but order maintained.

# %%
def clean_scene_list(scene_list):

    # take list of lists and just make a singular list
    scene_set = []

    for results in scene_list:
        for scene in results:
            scene_set.append(scene)

    # remove duplicates while maintaining order
    seen = set()
    seen_add = seen.add
    
    return [x for x in scene_set if not (x in seen or seen_add(x))]

# %%
tuned_model = models.load_model('saved_models/tuned_model')

# %% [markdown]
# ## Sliding Window

# %% [markdown]
# To get scenes from the entire film, we'll repeatedly run `generate_scenes()` for a subset of frames. Since we're limited by hardware, we can't load all of the film's frames at once. So we slide a "window" of 400 frames through the film, increasing by 100 each time. These are the first four ranges to be analyzed using this technique.
#
# - 0-399
# - 100-499
# - 200-599
# - 300-699
#
# By ensuring a healthy overlap of window ranges, we ensure that we capture a scene even if it straddles one of the windows. For example, a scene comprised of the frames (350, 450) won't be picked up in the first window, but will be in the second window. It's worth noting that each window analyzes nearly seven minutes of the film; the average scene is two minutes so there isn't too much danger of lengthy scenes not being identified.
#
# Below is a small test, limiting the total frames to 2,000 instead of all of the film's frames.

# %%
film = 'extremely_wicked'
threshold = 3000

x = 200

frame_choices = [] # holds all ranges for our sliding window

while x < (2000 - 200): # hard-coded a limit of 2000 frames, instead of all the film's frames, for demonstration purposes
    frame_choices.append(range(x - 200, x + 200)) # generates a range like (0, 400)
    x += 100 # increments by 100, so the second range is (100, 500)

scene_list = []

for frames in frame_choices:
    scene_list.append(generate_scenes(film, frames, threshold))

scene_list = clean_scene_list(scene_list)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 48s 1us/step
# Number of clusters: 19
#
# cluster	 count	 mcu probability
# 0 	 68 	 17.65%
# 3 	 138 	 48.55%
# Fails MCU check
#
# 2 	 64 	 48.44%
# 3 	 138 	 48.55%
# Fails MCU check
#
# 7 	 22 	 59.09%
# 13 	 12 	 66.67%
# Passes MCU check
#
# 3 	 138 	 48.55%
# 4 	 9 	 88.89%
# Fails MCU check
#
# Speaker A and B Clusters: [7, 13]
# Anchor Start/End Frames: 234 274
#
# Speaker A and B Clusters: [7, 13]
# Anchor Start/End Frames: 234 274
# Cutaway Clusters: [6]
# Expanded Start/End Frames: 234 274
#
# Number of clusters: 17
#
# cluster	 count	 mcu probability
# 0 	 64 	 48.44%
# 1 	 162 	 46.91%
# Fails MCU check
#
# 8 	 22 	 59.09%
# 13 	 12 	 66.67%
# Passes MCU check
#
# 1 	 162 	 46.91%
# 7 	 9 	 88.89%
# Fails MCU check
#
# 1 	 162 	 46.91%
# 2 	 62 	 38.71%
# Fails MCU check
#
# 1 	 162 	 46.91%
# 11 	 8 	 62.50%
# Fails MCU check
#
# Speaker A and B Clusters: [8, 13]
# Anchor Start/End Frames: 234 274
#
# Speaker A and B Clusters: [8, 13]
# Anchor Start/End Frames: 234 274
# Cutaway Clusters: [4]
# Expanded Start/End Frames: 234 274
#
# Number of clusters: 16
#
# cluster	 count	 mcu probability
# 1 	 175 	 44.00%
# 2 	 22 	 59.09%
# Fails MCU check
#
# 6 	 22 	 59.09%
# 8 	 11 	 72.73%
# Passes MCU check
#
# 1 	 175 	 44.00%
# 3 	 36 	 83.33%
# Fails MCU check
#
# 1 	 175 	 44.00%
# 9 	 8 	 62.50%
# Fails MCU check
#
# 1 	 175 	 44.00%
# 4 	 16 	 0.00%
# Fails MCU check
#
# Speaker A and B Clusters: [6, 8]
# Anchor Start/End Frames: 238 274
#
# Speaker A and B Clusters: [6, 8]
# Anchor Start/End Frames: 238 274
# Cutaway Clusters: [12]
# Expanded Start/End Frames: 235 274
#
# Number of clusters: 16
#
# cluster	 count	 mcu probability
# 4 	 181 	 48.07%
# 10 	 45 	 82.22%
# Fails MCU check
#
# 3 	 8 	 62.50%
# 4 	 181 	 48.07%
# Fails MCU check
#
# 4 	 181 	 48.07%
# 9 	 16 	 0.00%
# Fails MCU check
#
# 2 	 35 	 45.71%
# 4 	 181 	 48.07%
# Fails MCU check
#
# Number of clusters: 18
#
# cluster	 count	 mcu probability
# 1 	 112 	 39.29%
# 4 	 60 	 38.33%
# Fails MCU check
#
# 1 	 112 	 39.29%
# 10 	 8 	 62.50%
# Fails MCU check
#
# 0 	 104 	 69.23%
# 1 	 112 	 39.29%
# Fails MCU check
#
# 6 	 21 	 100.00%
# 7 	 28 	 96.43%
# Passes MCU check
#
# 1 	 112 	 39.29%
# 3 	 6 	 66.67%
# Fails MCU check
#
# Speaker A and B Clusters: [6, 7]
# Anchor Start/End Frames: 690 743
#
# Speaker A and B Clusters: [6, 7]
# Anchor Start/End Frames: 690 743
# Cutaway Clusters: [ 0  2 11]
# Expanded Start/End Frames: 690 743
#
# Number of clusters: 19
#
# cluster	 count	 mcu probability
# 1 	 111 	 41.44%
# 4 	 124 	 69.35%
# Fails MCU check
#
# 4 	 124 	 69.35%
# 7 	 16 	 31.25%
# Fails MCU check
#
# 5 	 28 	 96.43%
# 6 	 21 	 100.00%
# Passes MCU check
#
# 0 	 9 	 66.67%
# 1 	 111 	 41.44%
# Fails MCU check
#
# Speaker A and B Clusters: [5, 6]
# Anchor Start/End Frames: 690 743
#
# Speaker A and B Clusters: [5, 6]
# Anchor Start/End Frames: 690 743
# Cutaway Clusters: [ 4  7 11]
# Expanded Start/End Frames: 690 743
#
# Number of clusters: 18
#
# cluster	 count	 mcu probability
# 1 	 20 	 35.00%
# 6 	 190 	 53.16%
# Fails MCU check
#
# 0 	 21 	 28.57%
# 6 	 190 	 53.16%
# Fails MCU check
#
# 5 	 21 	 100.00%
# 13 	 28 	 96.43%
# Passes MCU check
#
# 6 	 190 	 53.16%
# 12 	 6 	 0.00%
# Fails MCU check
#
# 7 	 19 	 100.00%
# 9 	 23 	 95.65%
# Passes MCU check
#
# Speaker A and B Clusters: [5, 13]
# Anchor Start/End Frames: 690 743
#
# Speaker A and B Clusters: [7, 9]
# Anchor Start/End Frames: 616 997
#
# Speaker A and B Clusters: [5, 13]
# Anchor Start/End Frames: 690 743
# Cutaway Clusters: [ 6  1 16]
# Expanded Start/End Frames: 690 743
#
# Speaker A and B Clusters: [7, 9]
# Anchor Start/End Frames: 616 997
# Cutaway Clusters: [11  1 16  0 17  6 15 13  5 14  3  8 12  4 10  2]
# Expanded Start/End Frames: 600 999
#
# Number of clusters: 21
#
# cluster	 count	 mcu probability
# 6 	 20 	 100.00%
# 18 	 21 	 100.00%
# Passes MCU check
#
# 1 	 9 	 66.67%
# 2 	 180 	 43.89%
# Fails MCU check
#
# 2 	 180 	 43.89%
# 14 	 6 	 0.00%
# Fails MCU check
#
# 0 	 40 	 97.50%
# 5 	 23 	 95.65%
# Passes MCU check
#
# 0 	 40 	 97.50%
# 2 	 180 	 43.89%
# Fails MCU check
#
# Speaker A and B Clusters: [6, 18]
# Anchor Start/End Frames: 700 743
#
# Speaker A and B Clusters: [0, 5]
# Anchor Start/End Frames: 716 1098
#
# Speaker A and B Clusters: [6, 18]
# Anchor Start/End Frames: 700 743
# Cutaway Clusters: [2 0]
# Expanded Start/End Frames: 700 751
#
# Speaker A and B Clusters: [0, 5]
# Anchor Start/End Frames: 716 1098
# Cutaway Clusters: [ 6 18  2 16  1 17  7 14  4 12  3 20 19  9  8 15 10 11 13]
# Expanded Start/End Frames: 700 1099
#
# Number of clusters: 23
#
# cluster	 count	 mcu probability
# 0 	 115 	 40.87%
# 1 	 78 	 58.97%
# Fails MCU check
#
# 5 	 23 	 95.65%
# 21 	 17 	 100.00%
# Passes MCU check
#
# 1 	 78 	 58.97%
# 19 	 9 	 55.56%
# Passes MCU check
#
# 1 	 78 	 58.97%
# 4 	 16 	 100.00%
# Passes MCU check
#
# 10 	 13 	 100.00%
# 13 	 13 	 100.00%
# Passes MCU check
#
# Speaker A and B Clusters: [5, 21]
# Anchor Start/End Frames: 954 997
#
# Speaker A and B Clusters: [1, 19]
# Anchor Start/End Frames: 811 1189
#
# Speaker A and B Clusters: [1, 4]
# Anchor Start/End Frames: 811 1189
#
# Speaker A and B Clusters: [10, 13]
# Anchor Start/End Frames: 1149 1181
#
# Speaker A and B Clusters: [5, 21]
# Anchor Start/End Frames: 954 997
# Cutaway Clusters: [22]
# Expanded Start/End Frames: 954 997
#
# Speaker A and B Clusters: [1, 19]
# Anchor Start/End Frames: 811 1189
# Cutaway Clusters: [18  0  3 17 14  9  5 21 22 12 20  4 16  7  2 15 11  6 10 13]
# Expanded Start/End Frames: 800 1189
#
# Speaker A and B Clusters: [1, 4]
# Anchor Start/End Frames: 811 1189
# Cutaway Clusters: [18  0  3 17 14  9  5 21 22 12 19 20 16  7  2 15 11  6 10 13]
# Expanded Start/End Frames: 800 1189
#
# Speaker A and B Clusters: [10, 13]
# Anchor Start/End Frames: 1149 1181
# Cutaway Clusters: [1 0 6]
# Expanded Start/End Frames: 1128 1189
#
# Number of clusters: 22
#
# cluster	 count	 mcu probability
# 19 	 23 	 95.65%
# 20 	 17 	 100.00%
# Passes MCU check
#
# 1 	 21 	 100.00%
# 4 	 145 	 48.28%
# Fails MCU check
#
# 13 	 13 	 100.00%
# 15 	 19 	 100.00%
# Passes MCU check
#
# 3 	 19 	 21.05%
# 9 	 20 	 40.00%
# Fails MCU check
#
# 2 	 13 	 61.54%
# 8 	 14 	 100.00%
# Passes MCU check
#
# 0 	 15 	 100.00%
# 9 	 20 	 40.00%
# Fails MCU check
#
# Speaker A and B Clusters: [19, 20]
# Anchor Start/End Frames: 954 997
#
# Speaker A and B Clusters: [13, 15]
# Anchor Start/End Frames: 1136 1181
#
# Speaker A and B Clusters: [2, 8]
# Anchor Start/End Frames: 998 1234
#
# Speaker A and B Clusters: [19, 20]
# Anchor Start/End Frames: 954 997
# Cutaway Clusters: [11]
# Expanded Start/End Frames: 954 997
#
# Speaker A and B Clusters: [13, 15]
# Anchor Start/End Frames: 1136 1181
# Cutaway Clusters: [10  4]
# Expanded Start/End Frames: 1134 1189
#
# Speaker A and B Clusters: [2, 8]
# Anchor Start/End Frames: 998 1234
# Cutaway Clusters: [14  7 17  4  1 18  5  6 16 12  3 10 15 13  9]
# Expanded Start/End Frames: 998 1234
#
# Number of clusters: 19
#
# cluster	 count	 mcu probability
# 1 	 39 	 92.31%
# 8 	 154 	 51.30%
# Passes MCU check
#
# 6 	 19 	 100.00%
# 12 	 13 	 100.00%
# Passes MCU check
#
# 2 	 19 	 21.05%
# 9 	 20 	 40.00%
# Fails MCU check
#
# 3 	 30 	 100.00%
# 10 	 13 	 61.54%
# Passes MCU check
#
# 0 	 15 	 100.00%
# 9 	 20 	 40.00%
# Fails MCU check
#
# Speaker A and B Clusters: [1, 8]
# Anchor Start/End Frames: 1019 1399
#
# Speaker A and B Clusters: [6, 12]
# Anchor Start/End Frames: 1136 1181
#
# Speaker A and B Clusters: [3, 10]
# Anchor Start/End Frames: 1000 1381
#
# Speaker A and B Clusters: [1, 8]
# Anchor Start/End Frames: 1019 1399
# Cutaway Clusters: [ 3 13  4 17  7  5 16 11  2 15  6 12  9 10  0 14]
# Expanded Start/End Frames: 1019 1399
#
# Speaker A and B Clusters: [6, 12]
# Anchor Start/End Frames: 1136 1181
# Cutaway Clusters: [15  8]
# Expanded Start/End Frames: 1134 1189
#
# Speaker A and B Clusters: [3, 10]
# Anchor Start/End Frames: 1000 1381
# Cutaway Clusters: [13  4 18  8  1 17  7  5 16 11  2 15  6 12  9  0]
# Expanded Start/End Frames: 1000 1386
#
# Number of clusters: 19
#
# cluster	 count	 mcu probability
# 4 	 13 	 100.00%
# 6 	 19 	 100.00%
# Passes MCU check
#
# 3 	 198 	 53.54%
# 13 	 14 	 14.29%
# Fails MCU check
#
# 0 	 30 	 100.00%
# 7 	 13 	 61.54%
# Passes MCU check
#
# 3 	 198 	 53.54%
# 5 	 12 	 41.67%
# Fails MCU check
#
# 0 	 30 	 100.00%
# 3 	 198 	 53.54%
# Passes MCU check
#
# Speaker A and B Clusters: [4, 6]
# Anchor Start/End Frames: 1136 1181
#
# Speaker A and B Clusters: [0, 7]
# Anchor Start/End Frames: 1101 1396
#
# Speaker A and B Clusters: [0, 3]
# Anchor Start/End Frames: 1100 1499
#
# Speaker A and B Clusters: [4, 6]
# Anchor Start/End Frames: 1136 1181
# Cutaway Clusters: [8 3]
# Expanded Start/End Frames: 1134 1189
#
# Speaker A and B Clusters: [0, 7]
# Anchor Start/End Frames: 1101 1396
# Cutaway Clusters: [ 2 15 18  3  9  8  6  4 13  5  1 14]
# Expanded Start/End Frames: 1100 1449
#
# Speaker A and B Clusters: [0, 3]
# Anchor Start/End Frames: 1100 1499
# Cutaway Clusters: [ 2 15 18  9  8  6  4 13  5  7  1 14 17 16 12 10 11]
# Expanded Start/End Frames: 1100 1499
# Number of clusters: 14
#
# cluster	 count	 mcu probability
# 2 	 23 	 100.00%
# 7 	 13 	 61.54%
# Passes MCU check
#
# 0 	 217 	 55.30%
# 4 	 12 	 41.67%
# Fails MCU check
#
# 0 	 217 	 55.30%
# 2 	 23 	 100.00%
# Passes MCU check
#
# 0 	 217 	 55.30%
# 11 	 24 	 8.33%
# Fails MCU check
#
# 0 	 217 	 55.30%
# 8 	 18 	 100.00%
# Passes MCU check
#
# 0 	 217 	 55.30%
# 3 	 33 	 87.88%
# Passes MCU check
#
# Speaker A and B Clusters: [2, 7]
# Anchor Start/End Frames: 1215 1381
#
# Speaker A and B Clusters: [0, 2]
# Anchor Start/End Frames: 1200 1599
#
# Speaker A and B Clusters: [0, 8]
# Anchor Start/End Frames: 1200 1599
#
# Speaker A and B Clusters: [0, 3]
# Anchor Start/End Frames: 1200 1599
#
# Speaker A and B Clusters: [2, 7]
# Anchor Start/End Frames: 1215 1381
# Cutaway Clusters: [1 0 4]
# Expanded Start/End Frames: 1200 1386
#
# Speaker A and B Clusters: [0, 2]
# Anchor Start/End Frames: 1200 1599
# Cutaway Clusters: [ 4  7  1 10 12 13  6  3  5  9  8 11]
# Expanded Start/End Frames: 1200 1599
#
# Speaker A and B Clusters: [0, 8]
# Anchor Start/End Frames: 1200 1599
# Cutaway Clusters: [ 4  2  7  1 10 12 13  6  3  5  9 11]
# Expanded Start/End Frames: 1200 1599
#
# Speaker A and B Clusters: [0, 3]
# Anchor Start/End Frames: 1200 1599
# Cutaway Clusters: [ 4  2  7  1 10 12 13  6  5  9  8 11]
# Expanded Start/End Frames: 1200 1599
#
# Number of clusters: 15
#
# cluster	 count	 mcu probability
# 0 	 20 	 100.00%
# 1 	 195 	 56.92%
# Passes MCU check
#
# 1 	 195 	 56.92%
# 4 	 24 	 8.33%
# Fails MCU check
#
# 1 	 195 	 56.92%
# 3 	 18 	 100.00%
# Passes MCU check
#
# 1 	 195 	 56.92%
# 6 	 33 	 87.88%
# Passes MCU check
#
# 10 	 17 	 88.24%
# 13 	 14 	 92.86%
# Passes MCU check
#
# 2 	 22 	 100.00%
# 13 	 14 	 92.86%
# Passes MCU check
#
# 1 	 195 	 56.92%
# 2 	 22 	 100.00%
# Passes MCU check
#
# Speaker A and B Clusters: [0, 1]
# Anchor Start/End Frames: 1300 1699
#
# Speaker A and B Clusters: [1, 3]
# Anchor Start/End Frames: 1300 1699
#
# Speaker A and B Clusters: [1, 6]
# Anchor Start/End Frames: 1300 1699
#
# Speaker A and B Clusters: [10, 13]
# Anchor Start/End Frames: 1422 1653
#
# Speaker A and B Clusters: [2, 13]
# Anchor Start/End Frames: 1394 1662
#
# Speaker A and B Clusters: [1, 2]
# Anchor Start/End Frames: 1300 1699
#
# Speaker A and B Clusters: [0, 1]
# Anchor Start/End Frames: 1300 1699
# Cutaway Clusters: [12  2 10 14  7  6  5  8  3  4 13 11  9]
# Expanded Start/End Frames: 1300 1699
#
# Speaker A and B Clusters: [1, 3]
# Anchor Start/End Frames: 1300 1699
# Cutaway Clusters: [ 0 12  2 10 14  7  6  5  8  4 13 11  9]
# Expanded Start/End Frames: 1300 1699
#
# Speaker A and B Clusters: [1, 6]
# Anchor Start/End Frames: 1300 1699
# Cutaway Clusters: [ 0 12  2 10 14  7  5  8  3  4 13 11  9]
# Expanded Start/End Frames: 1300 1699
#
# Speaker A and B Clusters: [10, 13]
# Anchor Start/End Frames: 1422 1653
# Cutaway Clusters: [14  1  0  7  6  5  8  3  4  2 11]
# Expanded Start/End Frames: 1391 1672
#
# Speaker A and B Clusters: [2, 13]
# Anchor Start/End Frames: 1394 1662
# Cutaway Clusters: [ 1 10 14  0  7  6  5  8  3  4 11]
# Expanded Start/End Frames: 1391 1672
#
# Speaker A and B Clusters: [1, 2]
# Anchor Start/End Frames: 1300 1699
# Cutaway Clusters: [ 0 12 10 14  7  6  5  8  3  4 13 11  9]
# Expanded Start/End Frames: 1300 1699
#
# Number of clusters: 20
#
# cluster	 count	 mcu probability
# 2 	 122 	 54.10%
# 6 	 26 	 100.00%
# Passes MCU check
#
# 2 	 122 	 54.10%
# 5 	 33 	 87.88%
# Passes MCU check
#
# 7 	 14 	 92.86%
# 13 	 17 	 88.24%
# Passes MCU check
#
# 7 	 14 	 92.86%
# 17 	 19 	 100.00%
# Passes MCU check
#
# 2 	 122 	 54.10%
# 17 	 19 	 100.00%
# Passes MCU check
#
# 0 	 31 	 67.74%
# 1 	 30 	 93.33%
# Passes MCU check
#
# Speaker A and B Clusters: [2, 6]
# Anchor Start/End Frames: 1400 1799
#
# Speaker A and B Clusters: [2, 5]
# Anchor Start/End Frames: 1400 1799
#
# Speaker A and B Clusters: [7, 13]
# Anchor Start/End Frames: 1422 1653
#
# Speaker A and B Clusters: [7, 17]
# Anchor Start/End Frames: 1604 1662
#
# Speaker A and B Clusters: [2, 17]
# Anchor Start/End Frames: 1400 1799
#
# Speaker A and B Clusters: [0, 1]
# Anchor Start/End Frames: 1424 1759
#
# Speaker A and B Clusters: [2, 6]
# Anchor Start/End Frames: 1400 1799
# Cutaway Clusters: [13  0  1 19  9  5  3  4  8  7 17 16 14 18 15 11 12 10]
# Expanded Start/End Frames: 1400 1799
#
# Speaker A and B Clusters: [2, 5]
# Anchor Start/End Frames: 1400 1799
# Cutaway Clusters: [13  0  6  1 19  9  3  4  8  7 17 16 14 18 15 11 12 10]
# Expanded Start/End Frames: 1400 1799
#
# Speaker A and B Clusters: [7, 13]
# Anchor Start/End Frames: 1422 1653
# Cutaway Clusters: [ 0  2  6  1 19  9  5  3  4  8 17 16]
# Expanded Start/End Frames: 1400 1672
#
# Speaker A and B Clusters: [7, 17]
# Anchor Start/End Frames: 1604 1662
# Cutaway Clusters: [16 13  2]
# Expanded Start/End Frames: 1594 1672
#
# Speaker A and B Clusters: [2, 17]
# Anchor Start/End Frames: 1400 1799
# Cutaway Clusters: [13  0  6  1 19  9  5  3  4  8  7 16 14 18 15 11 12 10]
# Expanded Start/End Frames: 1400 1799
#
# Speaker A and B Clusters: [0, 1]
# Anchor Start/End Frames: 1424 1759
# Cutaway Clusters: [ 2  6 19  9  5  3  4  8 13  7 17 16 14 18 15]
# Expanded Start/End Frames: 1400 1764
#
# Number of clusters: 20
#
# cluster	 count	 mcu probability
# 7 	 24 	 8.33%
# 9 	 84 	 52.38%
# Fails MCU check
#
# 5 	 19 	 100.00%
# 9 	 84 	 52.38%
# Passes MCU check
#
# 2 	 30 	 76.67%
# 9 	 84 	 52.38%
# Passes MCU check
#
# 14 	 15 	 93.33%
# 15 	 16 	 81.25%
# Passes MCU check
#
# 0 	 40 	 62.50%
# 15 	 16 	 81.25%
# Passes MCU check
#
# 0 	 40 	 62.50%
# 9 	 84 	 52.38%
# Passes MCU check
#
# 1 	 28 	 100.00%
# 8 	 25 	 84.00%
# Passes MCU check
#
# 3 	 21 	 100.00%
# 4 	 13 	 69.23%
# Passes MCU check
#
# Speaker A and B Clusters: [5, 9]
# Anchor Start/End Frames: 1500 1893
#
# Speaker A and B Clusters: [2, 9]
# Anchor Start/End Frames: 1500 1893
#
# Speaker A and B Clusters: [14, 15]
# Anchor Start/End Frames: 1598 1653
#
# Speaker A and B Clusters: [0, 15]
# Anchor Start/End Frames: 1598 1899
#
# Speaker A and B Clusters: [0, 9]
# Anchor Start/End Frames: 1500 1899
#
# Speaker A and B Clusters: [1, 8]
# Anchor Start/End Frames: 1680 1759
#
# Speaker A and B Clusters: [3, 4]
# Anchor Start/End Frames: 1776 1870
#
# Speaker A and B Clusters: [5, 9]
# Anchor Start/End Frames: 1500 1893
# Cutaway Clusters: [ 7  2 11 15 14  0 18 13 10  1  8 17 19  3  4  6 16 12]
# Expanded Start/End Frames: 1500 1899
#
# Speaker A and B Clusters: [2, 9]
# Anchor Start/End Frames: 1500 1893
# Cutaway Clusters: [ 7  5 11 15 14  0 18 13 10  1  8 17 19  3  4  6 16 12]
# Expanded Start/End Frames: 1500 1899
#
# Speaker A and B Clusters: [14, 15]
# Anchor Start/End Frames: 1598 1653
# Cutaway Clusters: [ 0 18]
# Expanded Start/End Frames: 1598 1658
#
# Speaker A and B Clusters: [0, 15]
# Anchor Start/End Frames: 1598 1899
# Cutaway Clusters: [14 18  9 13 10  1  8 17 19  3  4  6 16 12  2]
# Expanded Start/End Frames: 1578 1899
#
# Speaker A and B Clusters: [0, 9]
# Anchor Start/End Frames: 1500 1899
# Cutaway Clusters: [ 7  5  2 11 15 14 18 13 10  1  8 17 19  3  4  6 16 12]
# Expanded Start/End Frames: 1500 1899
#
# Speaker A and B Clusters: [1, 8]
# Anchor Start/End Frames: 1680 1759
# Cutaway Clusters: [ 9 17 10]
# Expanded Start/End Frames: 1676 1764
#
# Speaker A and B Clusters: [3, 4]
# Anchor Start/End Frames: 1776 1870
# Cutaway Clusters: [ 6  9  0 16 12]
# Expanded Start/End Frames: 1776 1874

# %% [markdown]
# These functions worked as intended, identifying many scene possibilities. The high number of potential scenes suggests we should make the original scene-partitioning algorithm more discriminating.

# %%
scene_list
# Out:
# [(234, 274),
#  (235, 274),
#  (690, 743),
#  (600, 999),
#  (700, 751),
#  (700, 1099),
#  (954, 997),
#  (800, 1189),
#  (1128, 1189),
#  (1134, 1189),
#  (998, 1234),
#  (1019, 1399),
#  (1000, 1386),
#  (1100, 1449),
#  (1100, 1499),
#  (1200, 1386),
#  (1200, 1599),
#  (1300, 1699),
#  (1391, 1672),
#  (1400, 1799),
#  (1400, 1672),
#  (1594, 1672),
#  (1400, 1764),
#  (1500, 1899),
#  (1598, 1658),
#  (1578, 1899),
#  (1676, 1764),
#  (1776, 1874)]

# %% [markdown]
# The below code block is the same algorithm as before, except it slides the 400-frame window throughout ALL of the film's frames. However, this yielded an OOM error. To get around this hardware restraint, we could apply the window technique to just 2,000 frames at a time, like above. This implementation is similar to the sliding-window strategy itself, so we'll follow the same technique (and make sure there's sufficient overlap so no scenes are missed because they're straddling a subset of frames).

# %%
film = 'hustle'
threshold = 3000

x = 200

frame_choices = []
dialogue_folder = os.path.join('dialogue_frames', film)

while x < (len(os.listdir(dialogue_folder)) - 200):
    frame_choices.append(range(x - 200, x + 200))
    x += 100

scene_list = []

for frames in frame_choices:
    scene_list.append(generate_scenes(film, list(frames), threshold))

scene_list = clean_scene_list(scene_list)
